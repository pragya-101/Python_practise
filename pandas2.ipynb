# %%
#data Exploration With Pandasimport pandas as pd

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib .pyplot as plt
# %matplotlib inline
sns.set()

# %%
#load data

covid =pd.read_csv("covid.csv")
covid
# Out:
#          STATE ST_ABBR  STCNTY    COUNTY         FIPS  County FIPS  \
# 0      ALABAMA      AL    1001   Autauga   1001020100         1001
# 1      ALABAMA      AL    1001   Autauga   1001020200         1001
# 2      ALABAMA      AL    1001   Autauga   1001020300         1001
# 3      ALABAMA      AL    1001   Autauga   1001020400         1001
# 4      ALABAMA      AL    1001   Autauga   1001020500         1001
# ...        ...     ...     ...       ...          ...          ...
# 72831  WYOMING      WY   56043  Washakie  56043000200        56043
# 72832  WYOMING      WY   56043  Washakie  56043000301        56043
# 72833  WYOMING      WY   56043  Washakie  56043000302        56043
# 72834  WYOMING      WY   56045    Weston  56045951100        56045
# 72835  WYOMING      WY   56045    Weston  56045951300        56045
#
#                                           LOCATION Total Score  \
# 0        Census Tract 201, Autauga County, Alabama           7
# ...

# %%
covid_df = covid.copy(deep = True)
covid_df = covid.set_index("LOCATION")
covid_df
# Out:
#                                                STATE ST_ABBR  STCNTY  \
# LOCATION
# Census Tract 201, Autauga County, Alabama    ALABAMA      AL    1001
# Census Tract 202, Autauga County, Alabama    ALABAMA      AL    1001
# Census Tract 203, Autauga County, Alabama    ALABAMA      AL    1001
# Census Tract 204, Autauga County, Alabama    ALABAMA      AL    1001
# Census Tract 205, Autauga County, Alabama    ALABAMA      AL    1001
# ...                                              ...     ...     ...
# Census Tract 2, Washakie County, Wyoming     WYOMING      WY   56043
# Census Tract 3.01, Washakie County, Wyoming  WYOMING      WY   56043
# Census Tract 3.02, Washakie County, Wyoming  WYOMING      WY   56043
# Census Tract 9511, Weston County, Wyoming    WYOMING      WY   56045
# Census Tract 9513, Weston County, Wyoming    WYOMING      WY   56045
#
#                                                COUNTY         FIPS  \
# LOCATION
# ...

# %%
covid_df.describe()
# Out:
#              STCNTY          FIPS   County FIPS  Max Possible Score  \
# count  72836.000000  7.283600e+04  72836.000000        72836.000000
# mean   27830.694135  2.783095e+10  27830.694135           14.924927
# std    15813.578470  1.581358e+10  15813.578470            9.404650
# min     1001.000000  1.001020e+09   1001.000000            0.000000
# 25%    12127.000000  1.212708e+10  12127.000000            7.000000
# 50%    27131.000000  2.713107e+10  27131.000000           15.000000
# 75%    41039.000000  4.103900e+10  41039.000000           22.000000
# max    56045.000000  5.604595e+10  56045.000000           50.000000
#
#           HHA Score  \
# count  72836.000000
# mean       6.369845
# std        7.079037
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       15.000000
# max       15.000000
#
#        Low Income Area (LIA) County SAIPE - (Poverty Percentage)  \
# count                                       72836.000000
# ...

# %%
plt.figure(figsize=[15,15])
plt.subplot(2,2,1)
plt.xlabel("STCNTY")
covid_df['STCNTY'].hist()
plt.subplot(3,3,3)
plt.xlabel('FIPS')
covid_df['FIPS'].hist(bins=50)
plt.subplot(2,3,4)
plt.xlabel("FIPS")
plt.ylabel("STCNTY")
plt.scatter(covid_df["FIPS"],covid_df["STCNTY"])
plt.show()

# %%
total_cases = pd.read_csv('total_cases.csv')

# %%
total_cases
# Out:
#            date     World  Afghanistan  Albania  Algeria  Andorra   Angola  \
# 0    2019-12-31        27          NaN      NaN      NaN      NaN      NaN
# 1    2020-01-01        27          NaN      NaN      NaN      NaN      NaN
# 2    2020-01-02        27          NaN      NaN      NaN      NaN      NaN
# 3    2020-01-03        44          NaN      NaN      NaN      NaN      NaN
# 4    2020-01-04        44          NaN      NaN      NaN      NaN      NaN
# ..          ...       ...          ...      ...      ...      ...      ...
# 330  2020-11-25  59903030      45202.0  34300.0  77000.0   6351.0  14634.0
# 331  2020-11-26  60552696      45402.0  34944.0  78025.0   6428.0  14742.0
# 332  2020-11-27  61102596      45402.0  35600.0  79110.0   6534.0  14821.0
# 333  2020-11-28  61718735      45616.0  36245.0      NaN   6610.0      NaN
# 334  2020-11-29  62271031      45844.0  36790.0  81212.0   6670.0  15087.0
#
# ...

# %%
sample= total_cases.iloc[330:340,0:7]
sample
# Out:
#            date     World  Afghanistan  Albania  Algeria  Andorra   Angola
# 330  2020-11-25  59903030      45202.0  34300.0  77000.0   6351.0  14634.0
# 331  2020-11-26  60552696      45402.0  34944.0  78025.0   6428.0  14742.0
# 332  2020-11-27  61102596      45402.0  35600.0  79110.0   6534.0  14821.0
# 333  2020-11-28  61718735      45616.0  36245.0      NaN   6610.0      NaN
# 334  2020-11-29  62271031      45844.0  36790.0  81212.0   6670.0  15087.0

# %%
sample.describe()
# Out:
#               World   Afghanistan       Albania       Algeria      Andorra  \
# count  5.000000e+00      5.000000      5.000000      4.000000     5.000000
# mean   6.110962e+07  45493.200000  35575.800000  78836.750000  6518.600000
# std    9.335376e+05    244.730873    993.671576   1802.689357   130.202919
# min    5.990303e+07  45202.000000  34300.000000  77000.000000  6351.000000
# 25%    6.055270e+07  45402.000000  34944.000000  77768.750000  6428.000000
# 50%    6.110260e+07  45402.000000  35600.000000  78567.500000  6534.000000
# 75%    6.171874e+07  45616.000000  36245.000000  79635.500000  6610.000000
# max    6.227103e+07  45844.000000  36790.000000  81212.000000  6670.000000
#
#              Angola
# count      4.000000
# mean   14821.000000
# std      193.189027
# min    14634.000000
# 25%    14715.000000
# 50%    14781.500000
# 75%    14887.500000
# max    15087.000000

# %%
sample.plot(figsize = [15,14])
# Out:
# <AxesSubplot:>

# %%
sample.plot.bar(stacked=True,figsize =(15,15),fontsize=20)
# Out:
# <AxesSubplot:>

# %%
sample.plot.barh(stacked = False,figsize =(20,20),fontsize =30)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=[10,10])
plt.subplot(2,1,1)
plt.xlabel("Albania")
plt.ylabel("Algeria")
plt.scatter(sample["Albania"],sample["Algeria"])
plt.show()

# %%
plt.figure(figsize=[15,15])
plt.subplot(3,2,2)
plt.xlabel("World")
sample["World"].hist()
plt.show()

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 330 to 334
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         5 non-null      object
#  1   World        5 non-null      int64
#  2   Afghanistan  5 non-null      float64
#  3   Albania      5 non-null      float64
#  4   Algeria      4 non-null      float64
#  5   Andorra      5 non-null      float64
#  6   Angola       4 non-null      float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 412.0+ bytes

# %%
a = sns.load_dataset("trial")
a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-346573a6ce68> in <module>
# ----> 1 a = sns.load_dataset("trial")
#       2 a
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     484         if not os.path.exists(cache_path):
#     485             if name not in get_dataset_names():
# --> 486                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     487             urlretrieve(full_path, cache_path)
#     488         full_path = cache_path
#
# ValueError: 'trial' is not one of the example datasets.
